# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshu-ISM/Oil-and-Gas-data-analysis/blob/master/ThermalStimulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Radial form of Darcy's Law
#
# #1. $ q = \frac {kh (Pe - Pwf)}{141.2 \mu B ln(\frac{re}{rw})} $
#
# #2. $ \triangle P  = \frac {141.2q \mu B ln(re/rw)} {k h} $
#
# #3. $ Pr = Pwf + \frac {141.2q \mu B ln(r/rw)} {k h} $
#
# #4. $ q = \frac {kh (Pe - P)}{141.2 \mu B ln(\frac{re}{r})} $
#
# #5. $ \triangle P  = \frac {141.2q \mu B ln(re/r)} {k h} $
#
# #6. $ Pr = Pe -  \frac {141.2q \mu B ln(re/r)} {k h} $

# %%
###### CODE As follows #######

# %%
# See that the blue curve is of the unstimulated-thick oil scene. You can see that oil's pressure diminishes even before 
# it reaches the well. Where as, the orange curve (hot oil) is still energetic by the time it reaches the well

# %%
plt.figure(figsize=(10,6))

plt.plot(r,Pr_normal,linewidth='3',label=' without stimulation, oil viscocity = 1000 cp')

plt.plot(r,Pr_stim,linewidth='3',label='with stimulation, oil viscocity = 10 cp')


plt.grid()


plt.legend(loc='best')

plt.ylim(0,3000)

plt.xlim(0,1000)

plt.ylabel('Pressure (Psia)')

plt.xlabel('Radius from the wellbore,r(feet)')

plt.title('Qualitative Effect of Thermal Stimulation : Magic of oil viscosity reduction!')
# Out:
# Text(0.5, 1.0, 'Qualitative Effect of Thermal Stimulation : Magic of oil viscosity reduction!')

# %%
#Values used : 

[u,u_stim,q,pe,B,re]
# Out:
# [500, 200, 200, 3000, 1.125, 1000]
